# %%
import findspark
findspark.init()
import pyspark
from pyspark.sql import SparkSession
from pyspark.conf import SparkConf

# %%
# Disable AQE and adjust session parameters

# %%
conf = SparkConf() \
        .set("spark.driver.memory", "4G") \
        .set("spark.sql.autoBroadcastJoinThreshold", "-1") \
        .set("spark.sql.shuffle.partitions", "201") \
        .set("spark.sql.adaptive.enabled", "false")

spark = SparkSession\
        .builder\
        .master("local[8]")\
        .config(conf=conf)\
        .appName("Skewness") \
        .getOrCreate()
# Out:
# 24/03/19 22:44:44 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
# manually adds skew to the trip data - replace some of the pickup locations to arbitrary number (237)

# %%
import pyspark.sql.functions as F


def prepare_trips_data():
    pickupChange = [
        236, 132, 161, 186, 142, 141, 48, 239, 170, 162, 230, 163, 79, 234, 263, 140, 238, 107, 68, 138, 229, 249,
        237, 164, 90, 43, 100, 246, 231, 262, 113, 233, 143, 137, 114, 264, 148, 151
    ]

    res = spark.read\
        .parquet("/Users/shaytavor/Dropbox/Public/Knowledge Base/Spark/Data/TripData/*.parquet")\
        .withColumn(
            "PULocationID",
            F.when(F.col("PULocationID").isin(pickupChange), F.lit(237))
            .otherwise(F.col("PULocationID"))
        )
    return res

# %%
# join the trip data with the zip codes to get the location of each trip.

# %%
def join_skewed_data():
    tripsDF = prepare_trips_data()
    locationDF = spark.read.csv("/Users/shaytavor/Dropbox/Public/Knowledge Base/Spark/Data/TripData/zone_lookup.csv", header = 'True', inferSchema = 'True')

    tripsLocationDF = tripsDF\
        .join(locationDF, tripsDF.PULocationID == locationDF.LocationID)

    tripsLocationDF \
        .groupBy("Zone") \
        .agg(F.avg("trip_distance").alias("avg_trip_distance")) \
        .sort(F.col("avg_trip_distance").desc()) \
        .show(truncate=False, n=1000)

    tripsLocationDF \
        .groupBy("Borough") \
        .agg(F.avg("trip_distance").alias("avg_trip_distance")) \
        .sort(F.col("avg_trip_distance").desc()) \
        .show(truncate=False, n=1000)

# %%
# run the join - view SparkUI to detect the skewness

# %%
import time
startTime = time.time()
join_skewed_data()
print(f"Elapsed_time: {(time.time() - startTime)} seconds")
# Out:
# 24/03/19 23:23:44 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 24/03/19 23:23:45 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 24/03/19 23:23:45 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# +---------------------------------------------+------------------+
# |Zone                                         |avg_trip_distance |
# +---------------------------------------------+------------------+
# |Morrisania/Melrose                           |936.171469594594  |
# |Westchester Village/Unionport                |726.9454487179488 |
# |Crotona Park East                            |534.0415021459228 |
# |Corona                                       |392.7733024691358 |
# |Laurelton                                    |254.4450787401576 |
# |Prospect Park                                |220.04481675392645|
# |Starrett City                                |207.7077204301075 |
# |Borough Park                                 |190.78443686006852|
# |Brooklyn Heights                             |188.71234232486032|
# |Carroll Gardens                              |185.954820303816  |
# |Mount Hope                                   |159.89288188976388|
# |East Tremont                                 |133.24979750778823|
# |Brownsville                                  |123.45871559633028|
# |Prospect-Lefferts Gardens                    |121.44663551401896|
# |Cobble Hill                                  |101.05898066783818|
# |Bedford                                      |92.77543800861653 |
# |Clinton Hill                                 |86.72465346534668 |
# |Steinway                                     |84.1017581246669  |
# |East New York                                |83.2204262295082  |
# |Sunset Park West                             |82.22457291666652 |
# |Prospect Heights                             |76.73660276890305 |
# |Hamilton Heights                             |75.18469703454603 |
# |Crown Heights North                          |71.92685843568192 |
# |Soundview/Castle Hill                        |71.13588299024929 |
# |Park Slope                                   |62.528558980151836|
# |Flatbush/Ditmas Park                         |51.48884231536924 |
# |Boerum Hill                                  |50.55434658352817 |
# |Washington Heights North                     |49.536692882422315|
# |Central Harlem North                         |47.46770418006446 |
# |Highbridge                                   |44.25719953325547 |
# |Old Astoria                                  |41.75047963016465 |
# |East Williamsburg                            |36.22838750959822 |
# |Greenpoint                                   |29.447670511534742|
# |Astoria                                      |26.882231350330454|
# |Downtown Brooklyn/MetroTech                  |26.785050271962948|
# |Jamaica                                      |26.64071113908119 |
# |Washington Heights South                     |24.479795311527525|
# |Williamsburg (North Side)                    |22.2590466206215  |
# |East Harlem North                            |21.667535067557495|
# |Two Bridges/Seward Park                      |21.63877343932682 |
# |Long Island City/Queens Plaza                |20.679330796067187|
# |Chinatown                                    |19.654615841878545|
# |Marine Park/Floyd Bennett Field              |19.28268292682927 |
# |Fort Greene                                  |17.990933296352825|
# |Manhattanville                               |17.43711069165428 |
# |Jamaica Bay                                  |17.26571428571429 |
# |Battery Park City                            |17.056270464101157|
# |Queensbridge/Ravenswood                      |16.80556096005105 |
# |Mariners Harbor                              |16.502            |
# |Sunnyside                                    |16.1124151567443  |
# |Eltingville/Annadale/Prince's Bay            |15.805            |
# |East Harlem South                            |15.717624035186757|
# |Charleston/Tottenville                       |15.537792207792206|
# |Stuy Town/Peter Cooper Village               |14.157805510409506|
# |Port Richmond                                |13.566666666666665|
# |Arden Heights                                |12.921206896551721|
# |Oakwood                                      |12.500000000000002|
# |Baisley Park                                 |12.420550680122837|
# |World Trade Center                           |12.326534235460594|
# |Willets Point                                |12.28711111111111 |
# |Bloomfield/Emerson Hill                      |11.215771812080543|
# |South Jamaica                                |11.213798808735921|
# |Springfield Gardens South                    |11.205941935483882|
# |Rossville/Woodrow                            |11.028571428571428|
# |Clinton West                                 |10.972313696552282|
# |Rockaway Park                                |10.88683870967742 |
# |Rikers Island                                |10.71             |
# |Morningside Heights                          |10.66285295754535 |
# |Sheepshead Bay                               |10.367682119205307|
# |Alphabet City                                |10.320924562344558|
# |New Dorp/Midland Beach                       |9.958666666666666 |
# |Rosedale                                     |9.949256410256412 |
# |Gravesend                                    |9.892557471264366 |
# |Westerleigh                                  |9.717             |
# |Cambria Heights                              |9.681276102088162 |
# |Hammels/Arverne                              |9.650916398713827 |
# |East Elmhurst                                |9.581248957216074 |
# |Great Kills                                  |9.507142857142856 |
# |Far Rockaway                                 |9.341755485893415 |
# |Coney Island                                 |9.060583941605845 |
# |Flushing Meadows-Corona Park                 |9.005785756327262 |
# |Bloomingdale                                 |8.859590760733079 |
# |Bath Beach                                   |8.678482142857145 |
# |Freshkills Park                              |8.520000000000001 |
# |Briarwood/Jamaica Hills                      |8.328989205103042 |
# |Glen Oaks                                    |8.234374999999996 |
# |Heartland Village/Todt Hill                  |8.193030303030305 |
# |Breezy Point/Fort Tilden/Riis Beach          |8.152857142857142 |
# |Financial District South                     |8.151600345605596 |
# |Howard Beach                                 |8.073888888888883 |
# |Hudson Sq                                    |8.053414541395256 |
# |Financial District North                     |8.027126417671148 |
# |Bay Ridge                                    |7.95227973568282  |
# |Central Harlem                               |7.894364079797312 |
# |University Heights/Morris Heights            |7.809923566878992 |
# |Oakland Gardens                              |7.774621848739498 |
# |Ozone Park                                   |7.697134502923979 |
# |Highbridge Park                              |7.522150537634407 |
# |Bronx Park                                   |7.507454545454546 |
# |Williamsbridge/Olinville                     |7.444610552763826 |
# |Brighton Beach                               |7.434444444444445 |
# |NA                                           |7.317219626716715 |
# |Pelham Bay Park                              |7.255624999999999 |
# |Canarsie                                     |7.220092081031308 |
# |Grymes Hill/Clifton                          |7.216086956521738 |
# |College Point                                |6.993423423423425 |
# |Belmont                                      |6.949387755102041 |
# |Woodlawn/Wakefield                           |6.7604561403508745|
# |Co-Op City                                   |6.7508512628624855|
# |City Island                                  |6.632249999999999 |
# |Riverdale/North Riverdale/Fieldston          |6.62322033898305  |
# |SoHo                                         |6.6080888336055175|
# |Crotona Park                                 |6.568571428571429 |
# |West Brighton                                |6.567333333333333 |
# |Saint Albans                                 |6.558228299643278 |
# |Bayside                                      |6.508742857142854 |
# |Meatpacking/West Village West                |6.492376000805597 |
# |Hollis                                       |6.430233918128656 |
# |Bay Terrace/Fort Totten                      |6.36103092783505  |
# |Eastchester                                  |6.355099337748344 |
# |Red Hook                                     |6.353031249999999 |
# |Bronxdale                                    |6.3342086330935246|
# |Norwood                                      |6.2681519507186865|
# |Bedford Park                                 |6.104611973392461 |
# |Queens Village                               |6.10033333333333  |
# |Woodside                                     |6.08649273643642  |
# |Van Cortlandt Village                        |5.982171189979124 |
# |South Ozone Park                             |5.966737343141508 |
# |Bensonhurst East                             |5.919608938547483 |
# |Dyker Heights                                |5.893300492610839 |
# |Flushing                                     |5.889325337331337 |
# |Kew Gardens                                  |5.878270313757041 |
# |Stapleton                                    |5.862941176470589 |
# |Allerton/Pelham Gardens                      |5.834834123222749 |
# |Astoria Park                                 |5.767767857142857 |
# |Manhattan Beach                              |5.7642307692307675|
# |Bensonhurst West                             |5.762539267015709 |
# |Bellerose                                    |5.741683673469389 |
# |Pelham Parkway                               |5.720694864048336 |
# |Arrochar/Fort Wadsworth                      |5.714117647058823 |
# |Whitestone                                   |5.652328042328041 |
# |Erasmus                                      |5.586778242677825 |
# |Madison                                      |5.563260869565215 |
# |Randalls Island                              |5.554999999999998 |
# |Homecrest                                    |5.554188679245284 |
# |Maspeth                                      |5.480019723865867 |
# |Saint George/New Brighton                    |5.4625            |
# |Rego Park                                    |5.452716688227682 |
# |Richmond Hill                                |5.450824345146382 |
# |Springfield Gardens North                    |5.416478454680536 |
# |Bushwick North                               |5.379134396355345 |
# |Fresh Meadows                                |5.370373134328356 |
# |Crown Heights South                          |5.367432273262665 |
# |Inwood                                       |5.293711911357339 |
# |Windsor Terrace                              |5.286713091922006 |
# |Broad Channel                                |5.283333333333333 |
# |Middle Village                               |5.224166666666667 |
# |Kensington                                   |5.220225225225223 |
# |Kingsbridge Heights                          |5.189758672699846 |
# |Inwood Hill Park                             |5.182021276595745 |
# |North Corona                                 |5.174939024390243 |
# |Columbia Street                              |5.173636363636362 |
# |South Beach/Dongan Hills                     |5.151578947368421 |
# |Cypress Hills                                |5.146385869565219 |
# |Jamaica Estates                              |5.146094527363185 |
# |Sunset Park East                             |5.133974358974356 |
# |Forest Park/Highland Park                    |5.10923076923077  |
# |Ocean Hill                                   |5.102437673130194 |
# |Bushwick South                               |5.061859914813063 |
# |Murray Hill-Queens                           |5.0263276836158175|
# |Queensboro Hill                              |5.005671641791045 |
# |Flatlands                                    |4.9596761658031125|
# |Spuyten Duyvil/Kingsbridge                   |4.958495726495731 |
# |Hillcrest/Pomonok                            |4.932289156626507 |
# |DUMBO/Vinegar Hill                           |4.891477551020407 |
# |East New York/Pennsylvania Avenue            |4.8875076923076906|
# |Claremont/Bathgate                           |4.828062499999999 |
# |Auburndale                                   |4.77365671641791  |
# |Upper East Side South                        |4.77173548370929  |
# |Ridgewood                                    |4.690600000000001 |
# |Van Nest/Morris Park                         |4.655584082156603 |
# |Battery Park                                 |4.6529310034228075|
# |Stuyvesant Heights                           |4.629645542427493 |
# |Gowanus                                      |4.619724284199365 |
# |Little Italy/NoLiTa                          |4.611594776297067 |
# |Marble Hill                                  |4.589137931034485 |
# |Midwood                                      |4.5372147651006705|
# |Fordham South                                |4.494302788844622 |
# |Governor's Island/Ellis Island/Liberty Island|4.4816666666666665|
# |East Flatbush/Remsen Village                 |4.457099737532807 |
# |Forest Hills                                 |4.453775147928984 |
# |Ocean Parkway South                          |4.42828282828283  |
# |Van Cortlandt Park                           |4.400281690140844 |
# |Schuylerville/Edgewater Park                 |4.391903114186854 |
# |Seaport                                      |4.366082353856922 |
# |Brooklyn Navy Yard                           |4.349077380952382 |
# |Hunts Point                                  |4.343557312252964 |
# |Parkchester                                  |4.303219696969698 |
# |Country Club                                 |4.289047619047619 |
# |Soundview/Bruckner                           |4.274482758620687 |
# |Marine Park/Mill Basin                       |4.264965612104542 |
# |Woodhaven                                    |4.25597510373444  |
# |Williamsburg (South Side)                    |4.233515246508974 |
# |Green-Wood Cemetery                          |4.211999999999999 |
# |West Concourse                               |4.206558570483125 |
# |Jackson Heights                              |4.1431052478979415|
# |Roosevelt Island                             |4.136254480286731 |
# |East Flatbush/Farragut                       |4.131278458844135 |
# |West Farms/Bronx River                       |4.121221590909091 |
# |Elmhurst                                     |4.105206473214287 |
# |East Concourse/Concourse Village             |3.9111915887850492|
# |South Williamsburg                           |3.884078711985691 |
# |Pelham Bay                                   |3.7795299145299133|
# |Melrose South                                |3.524345114345113 |
# |East Flushing                                |3.489             |
# |Longwood                                     |3.463044982698962 |
# |Elmhurst/Maspeth                             |3.382097902097905 |
# |Kew Gardens Hills                            |3.325497287522603 |
# |Mott Haven/Port Morris                       |3.200712412587416 |
# |Glendale                                     |3.163811881188117 |
# |Long Island City/Hunters Point               |2.217302969267743 |
# |Douglaston                                   |1.707847826086956 |
# |Saint Michaels Cemetery/Woodside             |1.5838111019055496|
# |Newark Airport                               |0.8880582232893172|
# +---------------------------------------------+------------------+
# 24/03/19 23:23:53 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 24/03/19 23:23:53 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 24/03/19 23:23:54 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# [Stage 37:=========================================>            (156 + 1) / 201]
# +-------------+------------------+
# |Borough      |avg_trip_distance |
# +-------------+------------------+
# |Bronx        |60.56271240903504 |
# |Brooklyn     |54.57467611422346 |
# |Queens       |15.646755301422479|
# |Staten Island|11.551419472247497|
# |Unknown      |7.317219626716715 |
# |Manhattan    |5.401644745476663 |
# |EWR          |0.8880582232893172|
# +-------------+------------------+
#
# Elapsed_time: 17.378972053527832 seconds

# %%
# Dividing large partitions using derived column
# This function adds a column to the trips dataset, based on the timestamp, and explodes each row in the zip dataset.

# %%
def join_with_subsplit():
    partitions = 20
    tripsDF = prepare_trips_data()\
        .withColumn("day_mod", F.dayofyear(F.col("tpep_pickup_datetime"))).withColumn("day_mod", F.col("day_mod") % partitions)

    locationDf = spark\
        .read\
        .csv("/Users/shaytavor/Dropbox/Public/Knowledge Base/Spark/Data/TripData/zone_lookup.csv", header = 'True', inferSchema = 'True')\
        .withColumn("location_id_alt", F.array([F.lit(num) for num in range(0,partitions)])) \
        .withColumn("location_id_alt", F.explode(F.col("location_id_alt")))

    tripsLocationDF = tripsDF\
        .join(
            locationDf,
            (F.col("PULocationID") == F.col("LocationID")) & (F.col("location_id_alt") == F.col("day_mod"))
        )

    tripsLocationDF \
        .groupBy("Zone") \
        .agg(F.avg("trip_distance").alias("avg_trip_distance")) \
        .sort(F.col("avg_trip_distance").desc()) \
        .show(truncate=False, n=1000)

    tripsLocationDF \
        .groupBy("Borough") \
        .agg(F.avg("trip_distance").alias("avg_trip_distance")) \
        .sort(F.col("avg_trip_distance").desc()) \
        .show(truncate=False, n=1000)

# %%
startTime = time.time()
join_with_subsplit()
print(f"Elapsed_time: {(time.time() - startTime)} seconds")
# Out:
# +---------------------------------------------+------------------+
# |Zone                                         |avg_trip_distance |
# +---------------------------------------------+------------------+
# |Morrisania/Melrose                           |936.171469594595  |
# |Westchester Village/Unionport                |726.9454487179488 |
# |Crotona Park East                            |534.0415021459228 |
# |Corona                                       |392.7733024691358 |
# |Laurelton                                    |254.44507874015744|
# |Prospect Park                                |220.04481675392668|
# |Starrett City                                |207.7077204301075 |
# |Borough Park                                 |190.7844368600683 |
# |Brooklyn Heights                             |188.7123423248593 |
# |Carroll Gardens                              |185.9548203038162 |
# |Mount Hope                                   |159.8928818897638 |
# |East Tremont                                 |133.24979750778812|
# |Brownsville                                  |123.45871559633026|
# |Prospect-Lefferts Gardens                    |121.44663551401871|
# |Cobble Hill                                  |101.05898066783831|
# |Bedford                                      |92.77543800861658 |
# |Clinton Hill                                 |86.72465346534656 |
# |Steinway                                     |84.10175812466704 |
# |East New York                                |83.2204262295082  |
# |Sunset Park West                             |82.22457291666663 |
# |Prospect Heights                             |76.7366027689031  |
# |Hamilton Heights                             |75.18469703454598 |
# |Crown Heights North                          |71.92685843568196 |
# |Soundview/Castle Hill                        |71.13588299024919 |
# |Park Slope                                   |62.528558980151665|
# |Flatbush/Ditmas Park                         |51.48884231536927 |
# |Boerum Hill                                  |50.55434658352818 |
# |Washington Heights North                     |49.53669288242234 |
# |Central Harlem North                         |47.46770418006431 |
# |Highbridge                                   |44.25719953325553 |
# |Old Astoria                                  |41.750479630164676|
# |East Williamsburg                            |36.22838750959817 |
# |Greenpoint                                   |29.447670511534614|
# |Astoria                                      |26.88223135033048 |
# |Downtown Brooklyn/MetroTech                  |26.78505027196308 |
# |Jamaica                                      |26.64071113908119 |
# |Washington Heights South                     |24.47979531152755 |
# |Williamsburg (North Side)                    |22.259046620621618|
# |East Harlem North                            |21.667535067557388|
# |Two Bridges/Seward Park                      |21.638773439326634|
# |Long Island City/Queens Plaza                |20.679330796067234|
# |Chinatown                                    |19.65461584187843 |
# |Marine Park/Floyd Bennett Field              |19.282682926829267|
# |Fort Greene                                  |17.99093329635279 |
# |Manhattanville                               |17.4371106916543  |
# |Jamaica Bay                                  |17.265714285714285|
# |Battery Park City                            |17.056270464101175|
# |Queensbridge/Ravenswood                      |16.80556096005103 |
# |Mariners Harbor                              |16.502000000000002|
# |Sunnyside                                    |16.11241515674432 |
# |Eltingville/Annadale/Prince's Bay            |15.805            |
# |East Harlem South                            |15.717624035186821|
# |Charleston/Tottenville                       |15.537792207792206|
# |Stuy Town/Peter Cooper Village               |14.157805510409414|
# |Port Richmond                                |13.566666666666668|
# |Arden Heights                                |12.921206896551721|
# |Oakwood                                      |12.5              |
# |Baisley Park                                 |12.420550680122862|
# |World Trade Center                           |12.32653423546077 |
# |Willets Point                                |12.287111111111113|
# |Bloomfield/Emerson Hill                      |11.215771812080536|
# |South Jamaica                                |11.213798808735936|
# |Springfield Gardens South                    |11.205941935483871|
# |Rossville/Woodrow                            |11.028571428571428|
# |Clinton West                                 |10.972313696552286|
# |Rockaway Park                                |10.88683870967742 |
# |Rikers Island                                |10.71             |
# |Morningside Heights                          |10.662852957545345|
# |Sheepshead Bay                               |10.3676821192053  |
# |Alphabet City                                |10.320924562344542|
# |New Dorp/Midland Beach                       |9.958666666666666 |
# |Rosedale                                     |9.949256410256412 |
# |Gravesend                                    |9.892557471264368 |
# |Westerleigh                                  |9.717000000000002 |
# |Cambria Heights                              |9.681276102088168 |
# |Hammels/Arverne                              |9.650916398713827 |
# |East Elmhurst                                |9.581248957216063 |
# |Great Kills                                  |9.507142857142856 |
# |Far Rockaway                                 |9.341755485893415 |
# |Coney Island                                 |9.060583941605838 |
# |Flushing Meadows-Corona Park                 |9.005785756327251 |
# |Bloomingdale                                 |8.859590760733113 |
# |Bath Beach                                   |8.67848214285714  |
# |Freshkills Park                              |8.520000000000001 |
# |Briarwood/Jamaica Hills                      |8.328989205103042 |
# |Glen Oaks                                    |8.234375          |
# |Heartland Village/Todt Hill                  |8.193030303030303 |
# |Breezy Point/Fort Tilden/Riis Beach          |8.152857142857142 |
# |Financial District South                     |8.151600345605527 |
# |Howard Beach                                 |8.07388888888889  |
# |Hudson Sq                                    |8.053414541395256 |
# |Financial District North                     |8.027126417671164 |
# |Bay Ridge                                    |7.95227973568282  |
# |Central Harlem                               |7.8943640797972705|
# |University Heights/Morris Heights            |7.809923566878982 |
# |Oakland Gardens                              |7.7746218487394945|
# |Ozone Park                                   |7.697134502923978 |
# |Highbridge Park                              |7.522150537634407 |
# |Bronx Park                                   |7.507454545454545 |
# |Williamsbridge/Olinville                     |7.444610552763819 |
# |Brighton Beach                               |7.434444444444444 |
# |NA                                           |7.317219626716755 |
# |Pelham Bay Park                              |7.255625          |
# |Canarsie                                     |7.220092081031307 |
# |Grymes Hill/Clifton                          |7.216086956521739 |
# |College Point                                |6.9934234234234225|
# |Belmont                                      |6.94938775510204  |
# |Woodlawn/Wakefield                           |6.760456140350876 |
# |Co-Op City                                   |6.750851262862489 |
# |City Island                                  |6.632250000000001 |
# |Riverdale/North Riverdale/Fieldston          |6.6232203389830495|
# |SoHo                                         |6.608088833605432 |
# |Crotona Park                                 |6.5685714285714285|
# |West Brighton                                |6.567333333333334 |
# |Saint Albans                                 |6.558228299643283 |
# |Bayside                                      |6.508742857142857 |
# |Meatpacking/West Village West                |6.492376000805685 |
# |Hollis                                       |6.430233918128654 |
# |Bay Terrace/Fort Totten                      |6.36103092783505  |
# |Eastchester                                  |6.355099337748346 |
# |Red Hook                                     |6.35303125        |
# |Bronxdale                                    |6.334208633093526 |
# |Norwood                                      |6.2681519507186865|
# |Bedford Park                                 |6.104611973392462 |
# |Queens Village                               |6.100333333333333 |
# |Woodside                                     |6.086492736436406 |
# |Van Cortlandt Village                        |5.982171189979122 |
# |South Ozone Park                             |5.966737343141498 |
# |Bensonhurst East                             |5.919608938547485 |
# |Dyker Heights                                |5.893300492610837 |
# |Flushing                                     |5.889325337331334 |
# |Kew Gardens                                  |5.878270313757039 |
# |Stapleton                                    |5.8629411764705885|
# |Allerton/Pelham Gardens                      |5.834834123222747 |
# |Astoria Park                                 |5.767767857142858 |
# |Manhattan Beach                              |5.764230769230768 |
# |Bensonhurst West                             |5.762539267015707 |
# |Bellerose                                    |5.741683673469389 |
# |Pelham Parkway                               |5.720694864048339 |
# |Arrochar/Fort Wadsworth                      |5.714117647058822 |
# |Whitestone                                   |5.652328042328042 |
# |Erasmus                                      |5.586778242677823 |
# |Madison                                      |5.563260869565217 |
# |Randalls Island                              |5.554999999999999 |
# |Homecrest                                    |5.554188679245284 |
# |Maspeth                                      |5.480019723865877 |
# |Saint George/New Brighton                    |5.4624999999999995|
# |Rego Park                                    |5.452716688227684 |
# |Richmond Hill                                |5.450824345146378 |
# |Springfield Gardens North                    |5.416478454680535 |
# |Bushwick North                               |5.379134396355352 |
# |Fresh Meadows                                |5.370373134328359 |
# |Crown Heights South                          |5.367432273262663 |
# |Inwood                                       |5.293711911357341 |
# |Windsor Terrace                              |5.286713091922006 |
# |Broad Channel                                |5.283333333333333 |
# |Middle Village                               |5.224166666666666 |
# |Kensington                                   |5.220225225225225 |
# |Kingsbridge Heights                          |5.189758672699848 |
# |Inwood Hill Park                             |5.182021276595745 |
# |North Corona                                 |5.174939024390244 |
# |Columbia Street                              |5.173636363636364 |
# |South Beach/Dongan Hills                     |5.151578947368421 |
# |Cypress Hills                                |5.146385869565218 |
# |Jamaica Estates                              |5.146094527363184 |
# |Sunset Park East                             |5.133974358974358 |
# |Forest Park/Highland Park                    |5.109230769230769 |
# |Ocean Hill                                   |5.102437673130196 |
# |Bushwick South                               |5.061859914813064 |
# |Murray Hill-Queens                           |5.026327683615819 |
# |Queensboro Hill                              |5.005671641791045 |
# |Flatlands                                    |4.959676165803108 |
# |Spuyten Duyvil/Kingsbridge                   |4.958495726495728 |
# |Hillcrest/Pomonok                            |4.932289156626507 |
# |DUMBO/Vinegar Hill                           |4.891477551020409 |
# |East New York/Pennsylvania Avenue            |4.887507692307692 |
# |Claremont/Bathgate                           |4.828062499999999 |
# |Auburndale                                   |4.773656716417911 |
# |Upper East Side South                        |4.771735483708311 |
# |Ridgewood                                    |4.6906            |
# |Van Nest/Morris Park                         |4.655584082156611 |
# |Battery Park                                 |4.6529310034228075|
# |Stuyvesant Heights                           |4.6296455424274985|
# |Gowanus                                      |4.619724284199363 |
# |Little Italy/NoLiTa                          |4.611594776297007 |
# |Marble Hill                                  |4.589137931034483 |
# |Midwood                                      |4.537214765100671 |
# |Fordham South                                |4.494302788844621 |
# |Governor's Island/Ellis Island/Liberty Island|4.481666666666667 |
# |East Flatbush/Remsen Village                 |4.457099737532808 |
# |Forest Hills                                 |4.453775147928994 |
# |Ocean Parkway South                          |4.428282828282828 |
# |Van Cortlandt Park                           |4.400281690140845 |
# |Schuylerville/Edgewater Park                 |4.39190311418685  |
# |Seaport                                      |4.366082353856934 |
# |Brooklyn Navy Yard                           |4.34907738095238  |
# |Hunts Point                                  |4.3435573122529645|
# |Parkchester                                  |4.303219696969696 |
# |Country Club                                 |4.289047619047619 |
# |Soundview/Bruckner                           |4.274482758620689 |
# |Marine Park/Mill Basin                       |4.26496561210454  |
# |Woodhaven                                    |4.25597510373444  |
# |Williamsburg (South Side)                    |4.233515246508977 |
# |Green-Wood Cemetery                          |4.212000000000001 |
# |West Concourse                               |4.206558570483125 |
# |Jackson Heights                              |4.1431052478979415|
# |Roosevelt Island                             |4.136254480286737 |
# |East Flatbush/Farragut                       |4.131278458844134 |
# |West Farms/Bronx River                       |4.121221590909091 |
# |Elmhurst                                     |4.105206473214285 |
# |East Concourse/Concourse Village             |3.911191588785046 |
# |South Williamsburg                           |3.8840787119856883|
# |Pelham Bay                                   |3.7795299145299137|
# |Melrose South                                |3.524345114345115 |
# |East Flushing                                |3.4890000000000003|
# |Longwood                                     |3.4630449826989618|
# |Elmhurst/Maspeth                             |3.382097902097902 |
# |Kew Gardens Hills                            |3.3254972875226043|
# |Mott Haven/Port Morris                       |3.200712412587413 |
# |Glendale                                     |3.1638118811881197|
# |Long Island City/Hunters Point               |2.217302969267754 |
# |Douglaston                                   |1.7078478260869563|
# |Saint Michaels Cemetery/Woodside             |1.583811101905551 |
# |Newark Airport                               |0.8880582232893158|
# +---------------------------------------------+------------------+
# [Stage 70:=================================================>    (183 + 1) / 201]
# +-------------+------------------+
# |Borough      |avg_trip_distance |
# +-------------+------------------+
# |Bronx        |60.562712409035065|
# |Brooklyn     |54.57467611422333 |
# |Queens       |15.646755301422477|
# |Staten Island|11.551419472247497|
# |Unknown      |7.317219626716755 |
# |Manhattan    |5.401644745475775 |
# |EWR          |0.8880582232893158|
# +-------------+------------------+
#
# Elapsed_time: 17.945346117019653 seconds

# %%
# Using AQE

# %%
conf = SparkConf() \
        .set("spark.driver.memory", "4G") \
        .set("spark.sql.autoBroadcastJoinThreshold", "-1") \
        .set("spark.sql.shuffle.partitions", "201") \
        .set("spark.sql.adaptive.enabled", "true") \
        .set("spark.sql.adaptive.coalescePartitions.enabled", "false") \
        .set("spark.sql.adaptive.skewJoin.enabled", "true") \
        .set("spark.sql.adaptive.skewJoin.skewedPartitionFactor", "3") \
        .set("spark.sql.adaptive.skewJoin.skewedPartitionThresholdInBytes", "256K")

spark = SparkSession\
        .builder\
        .master("local[8]")\
        .config(conf=conf)\
        .appName("Skewness") \
        .getOrCreate()

# %%
startTime = time.time()
join_skewed_data()
print(f"Elapsed_time: {(time.time() - startTime)} seconds")
# Out:
# 24/03/20 00:02:42 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 24/03/20 00:02:43 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# +---------------------------------------------+------------------+
# |Zone                                         |avg_trip_distance |
# +---------------------------------------------+------------------+
# |Morrisania/Melrose                           |936.171469594594  |
# |Westchester Village/Unionport                |726.9454487179488 |
# |Crotona Park East                            |534.0415021459228 |
# |Corona                                       |392.7733024691358 |
# |Laurelton                                    |254.4450787401576 |
# |Prospect Park                                |220.04481675392645|
# |Starrett City                                |207.7077204301075 |
# |Borough Park                                 |190.78443686006852|
# |Brooklyn Heights                             |188.71234232486032|
# |Carroll Gardens                              |185.954820303816  |
# |Mount Hope                                   |159.89288188976388|
# |East Tremont                                 |133.24979750778823|
# |Brownsville                                  |123.45871559633028|
# |Prospect-Lefferts Gardens                    |121.44663551401896|
# |Cobble Hill                                  |101.05898066783818|
# |Bedford                                      |92.77543800861653 |
# |Clinton Hill                                 |86.72465346534668 |
# |Steinway                                     |84.1017581246669  |
# |East New York                                |83.2204262295082  |
# |Sunset Park West                             |82.22457291666652 |
# |Prospect Heights                             |76.73660276890305 |
# |Hamilton Heights                             |75.18469703454603 |
# |Crown Heights North                          |71.92685843568192 |
# |Soundview/Castle Hill                        |71.13588299024929 |
# |Park Slope                                   |62.528558980151836|
# |Flatbush/Ditmas Park                         |51.48884231536924 |
# |Boerum Hill                                  |50.55434658352817 |
# |Washington Heights North                     |49.536692882422315|
# |Central Harlem North                         |47.46770418006446 |
# |Highbridge                                   |44.25719953325547 |
# |Old Astoria                                  |41.75047963016465 |
# |East Williamsburg                            |36.22838750959822 |
# |Greenpoint                                   |29.447670511534742|
# |Astoria                                      |26.882231350330454|
# |Downtown Brooklyn/MetroTech                  |26.785050271962948|
# |Jamaica                                      |26.64071113908119 |
# |Washington Heights South                     |24.479795311527525|
# |Williamsburg (North Side)                    |22.2590466206215  |
# |East Harlem North                            |21.667535067557495|
# |Two Bridges/Seward Park                      |21.63877343932682 |
# |Long Island City/Queens Plaza                |20.679330796067187|
# |Chinatown                                    |19.654615841878545|
# |Marine Park/Floyd Bennett Field              |19.28268292682927 |
# |Fort Greene                                  |17.990933296352825|
# |Manhattanville                               |17.43711069165428 |
# |Jamaica Bay                                  |17.26571428571429 |
# |Battery Park City                            |17.056270464101157|
# |Queensbridge/Ravenswood                      |16.80556096005105 |
# |Mariners Harbor                              |16.502            |
# |Sunnyside                                    |16.1124151567443  |
# |Eltingville/Annadale/Prince's Bay            |15.805            |
# |East Harlem South                            |15.717624035186757|
# |Charleston/Tottenville                       |15.537792207792206|
# |Stuy Town/Peter Cooper Village               |14.157805510409506|
# |Port Richmond                                |13.566666666666665|
# |Arden Heights                                |12.921206896551721|
# |Oakwood                                      |12.500000000000002|
# |Baisley Park                                 |12.420550680122837|
# |World Trade Center                           |12.326534235460594|
# |Willets Point                                |12.28711111111111 |
# |Bloomfield/Emerson Hill                      |11.215771812080543|
# |South Jamaica                                |11.213798808735921|
# |Springfield Gardens South                    |11.205941935483882|
# |Rossville/Woodrow                            |11.028571428571428|
# |Clinton West                                 |10.972313696552282|
# |Rockaway Park                                |10.88683870967742 |
# |Rikers Island                                |10.71             |
# |Morningside Heights                          |10.66285295754535 |
# |Sheepshead Bay                               |10.367682119205307|
# |Alphabet City                                |10.320924562344558|
# |New Dorp/Midland Beach                       |9.958666666666666 |
# |Rosedale                                     |9.949256410256412 |
# |Gravesend                                    |9.892557471264366 |
# |Westerleigh                                  |9.717             |
# |Cambria Heights                              |9.681276102088162 |
# |Hammels/Arverne                              |9.650916398713827 |
# |East Elmhurst                                |9.581248957216074 |
# |Great Kills                                  |9.507142857142856 |
# |Far Rockaway                                 |9.341755485893415 |
# |Coney Island                                 |9.060583941605845 |
# |Flushing Meadows-Corona Park                 |9.005785756327262 |
# |Bloomingdale                                 |8.859590760733079 |
# |Bath Beach                                   |8.678482142857145 |
# |Freshkills Park                              |8.520000000000001 |
# |Briarwood/Jamaica Hills                      |8.328989205103042 |
# |Glen Oaks                                    |8.234374999999996 |
# |Heartland Village/Todt Hill                  |8.193030303030305 |
# |Breezy Point/Fort Tilden/Riis Beach          |8.152857142857142 |
# |Financial District South                     |8.151600345605596 |
# |Howard Beach                                 |8.073888888888883 |
# |Hudson Sq                                    |8.053414541395256 |
# |Financial District North                     |8.027126417671148 |
# |Bay Ridge                                    |7.95227973568282  |
# |Central Harlem                               |7.894364079797312 |
# |University Heights/Morris Heights            |7.809923566878992 |
# |Oakland Gardens                              |7.774621848739498 |
# |Ozone Park                                   |7.697134502923979 |
# |Highbridge Park                              |7.522150537634407 |
# |Bronx Park                                   |7.507454545454546 |
# |Williamsbridge/Olinville                     |7.444610552763826 |
# |Brighton Beach                               |7.434444444444445 |
# |NA                                           |7.317219626716715 |
# |Pelham Bay Park                              |7.255624999999999 |
# |Canarsie                                     |7.220092081031308 |
# |Grymes Hill/Clifton                          |7.216086956521738 |
# |College Point                                |6.993423423423425 |
# |Belmont                                      |6.949387755102041 |
# |Woodlawn/Wakefield                           |6.7604561403508745|
# |Co-Op City                                   |6.7508512628624855|
# |City Island                                  |6.632249999999999 |
# |Riverdale/North Riverdale/Fieldston          |6.62322033898305  |
# |SoHo                                         |6.6080888336055175|
# |Crotona Park                                 |6.568571428571429 |
# |West Brighton                                |6.567333333333333 |
# |Saint Albans                                 |6.558228299643278 |
# |Bayside                                      |6.508742857142854 |
# |Meatpacking/West Village West                |6.492376000805597 |
# |Hollis                                       |6.430233918128656 |
# |Bay Terrace/Fort Totten                      |6.36103092783505  |
# |Eastchester                                  |6.355099337748344 |
# |Red Hook                                     |6.353031249999999 |
# |Bronxdale                                    |6.3342086330935246|
# |Norwood                                      |6.2681519507186865|
# |Bedford Park                                 |6.104611973392461 |
# |Queens Village                               |6.10033333333333  |
# |Woodside                                     |6.08649273643642  |
# |Van Cortlandt Village                        |5.982171189979124 |
# |South Ozone Park                             |5.966737343141508 |
# |Bensonhurst East                             |5.919608938547483 |
# |Dyker Heights                                |5.893300492610839 |
# |Flushing                                     |5.889325337331337 |
# |Kew Gardens                                  |5.878270313757041 |
# |Stapleton                                    |5.862941176470589 |
# |Allerton/Pelham Gardens                      |5.834834123222749 |
# |Astoria Park                                 |5.767767857142857 |
# |Manhattan Beach                              |5.7642307692307675|
# |Bensonhurst West                             |5.762539267015709 |
# |Bellerose                                    |5.741683673469389 |
# |Pelham Parkway                               |5.720694864048336 |
# |Arrochar/Fort Wadsworth                      |5.714117647058823 |
# |Whitestone                                   |5.652328042328041 |
# |Erasmus                                      |5.586778242677825 |
# |Madison                                      |5.563260869565215 |
# |Randalls Island                              |5.554999999999998 |
# |Homecrest                                    |5.554188679245284 |
# |Maspeth                                      |5.480019723865867 |
# |Saint George/New Brighton                    |5.4625            |
# |Rego Park                                    |5.452716688227682 |
# |Richmond Hill                                |5.450824345146382 |
# |Springfield Gardens North                    |5.416478454680536 |
# |Bushwick North                               |5.379134396355345 |
# |Fresh Meadows                                |5.370373134328356 |
# |Crown Heights South                          |5.367432273262665 |
# |Inwood                                       |5.293711911357339 |
# |Windsor Terrace                              |5.286713091922006 |
# |Broad Channel                                |5.283333333333333 |
# |Middle Village                               |5.224166666666667 |
# |Kensington                                   |5.220225225225223 |
# |Kingsbridge Heights                          |5.189758672699846 |
# |Inwood Hill Park                             |5.182021276595745 |
# |North Corona                                 |5.174939024390243 |
# |Columbia Street                              |5.173636363636362 |
# |South Beach/Dongan Hills                     |5.151578947368421 |
# |Cypress Hills                                |5.146385869565219 |
# |Jamaica Estates                              |5.146094527363185 |
# |Sunset Park East                             |5.133974358974356 |
# |Forest Park/Highland Park                    |5.10923076923077  |
# |Ocean Hill                                   |5.102437673130194 |
# |Bushwick South                               |5.061859914813063 |
# |Murray Hill-Queens                           |5.0263276836158175|
# |Queensboro Hill                              |5.005671641791045 |
# |Flatlands                                    |4.9596761658031125|
# |Spuyten Duyvil/Kingsbridge                   |4.958495726495731 |
# |Hillcrest/Pomonok                            |4.932289156626507 |
# |DUMBO/Vinegar Hill                           |4.891477551020407 |
# |East New York/Pennsylvania Avenue            |4.8875076923076906|
# |Claremont/Bathgate                           |4.828062499999999 |
# |Auburndale                                   |4.77365671641791  |
# |Upper East Side South                        |4.771735483709171 |
# |Ridgewood                                    |4.690600000000001 |
# |Van Nest/Morris Park                         |4.655584082156603 |
# |Battery Park                                 |4.6529310034228075|
# |Stuyvesant Heights                           |4.629645542427493 |
# |Gowanus                                      |4.619724284199365 |
# |Little Italy/NoLiTa                          |4.611594776297067 |
# |Marble Hill                                  |4.589137931034485 |
# |Midwood                                      |4.5372147651006705|
# |Fordham South                                |4.494302788844622 |
# |Governor's Island/Ellis Island/Liberty Island|4.4816666666666665|
# |East Flatbush/Remsen Village                 |4.457099737532807 |
# |Forest Hills                                 |4.453775147928984 |
# |Ocean Parkway South                          |4.42828282828283  |
# |Van Cortlandt Park                           |4.400281690140844 |
# |Schuylerville/Edgewater Park                 |4.391903114186854 |
# |Seaport                                      |4.366082353856922 |
# |Brooklyn Navy Yard                           |4.349077380952382 |
# |Hunts Point                                  |4.343557312252964 |
# |Parkchester                                  |4.303219696969698 |
# |Country Club                                 |4.289047619047619 |
# |Soundview/Bruckner                           |4.274482758620687 |
# |Marine Park/Mill Basin                       |4.264965612104542 |
# |Woodhaven                                    |4.25597510373444  |
# |Williamsburg (South Side)                    |4.233515246508974 |
# |Green-Wood Cemetery                          |4.211999999999999 |
# |West Concourse                               |4.206558570483125 |
# |Jackson Heights                              |4.1431052478979415|
# |Roosevelt Island                             |4.136254480286731 |
# |East Flatbush/Farragut                       |4.131278458844135 |
# |West Farms/Bronx River                       |4.121221590909091 |
# |Elmhurst                                     |4.105206473214287 |
# |East Concourse/Concourse Village             |3.9111915887850492|
# |South Williamsburg                           |3.884078711985691 |
# |Pelham Bay                                   |3.7795299145299133|
# |Melrose South                                |3.524345114345113 |
# |East Flushing                                |3.489             |
# |Longwood                                     |3.463044982698962 |
# |Elmhurst/Maspeth                             |3.382097902097905 |
# |Kew Gardens Hills                            |3.325497287522603 |
# |Mott Haven/Port Morris                       |3.200712412587416 |
# |Glendale                                     |3.163811881188117 |
# |Long Island City/Hunters Point               |2.217302969267743 |
# |Douglaston                                   |1.707847826086956 |
# |Saint Michaels Cemetery/Woodside             |1.5838111019055496|
# |Newark Airport                               |0.8880582232893172|
# +---------------------------------------------+------------------+
# 24/03/20 00:02:50 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 24/03/20 00:02:51 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# [Stage 130:========================================>            (153 + 1) / 202]
# +-------------+------------------+
# |Borough      |avg_trip_distance |
# +-------------+------------------+
# |Bronx        |60.56271240903504 |
# |Brooklyn     |54.57467611422346 |
# |Queens       |15.646755301422479|
# |Staten Island|11.551419472247497|
# |Unknown      |7.317219626716715 |
# |Manhattan    |5.401644745476554 |
# |EWR          |0.8880582232893172|
# +-------------+------------------+
#
# Elapsed_time: 15.636811017990112 seconds
